# %% [markdown]
# # Image Classification with Transfer Learning

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, Model
from keras.layers import Dropout, Flatten, Dense, InputLayer, GlobalAveragePooling2D, Activation, Conv2D, MaxPool2D
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.preprocessing import image
from keras.callbacks import Callback
from keras import optimizers
from keras import applications
from keras.utils import np_utils

from sklearn.metrics import cohen_kappa_score

import os, sys, timeit
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2     

from IPython.display import display
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Helper functions

# %%
from sklearn.datasets import load_files
from functools import partial

# define function to load train, test, and validation datasets
def load_dataset(path, num_classes):
    data = load_files(path)
    files = np.array(data.filenames)
    targets = np_utils.to_categorical(np.array(data.target), num_classes=num_classes)
    
    return files, targets, data.target_names


def path_to_3d_tensor(img_path, target_size=None):
    img = image.load_img(img_path, target_size=target_size)
    img_array = image.img_to_array(img) / 255
    return img_array

def path_to_4d_tensor(img_path, target_size=None):
    img_array = path_to_3d_tensor(img_path, target_size)
    return np.expand_dims(img_array, axis=0) # (1, 224, 224, 3)

def dataset_to_4d_tensor(path, num_classes, target_size=None, num_of_image_to_load=None):
    files, y, classes = load_dataset(path, num_classes)
    
    if not num_of_image_to_load:
        num_of_image_to_load = len(files)
    
    X=[]
        
    for f in files[:num_of_image_to_load]:
        X.append(path_to_3d_tensor(f, target_size))
        
    return np.array(X), y[:num_of_image_to_load], classes

# %% [markdown]
# ### Preparations

# %%
# dimensions of our images.
img_width, img_height = 224, 224

# data locations
train_data_dir = 'data/train'
valid_data_dir = 'data/valid'
test_data_dir = 'data/test'

# saved model directory
saved_model_dir = 'saved_models'

nb_train_samples = 1460
nb_valid_samples = 180
nb_test_samples = 140

batch_size = 20

if not os.path.exists(saved_model_dir):
    os.mkdir(saved_model_dir)

# %% [markdown]
# ### Load Datasets

# %%
X_train, y_train, classes = dataset_to_4d_tensor(train_data_dir, 19, (img_width, img_height))
X_valid, y_valid, classes1 = dataset_to_4d_tensor(valid_data_dir, 19, (img_width, img_height))
X_test, y_test, classes2 = dataset_to_4d_tensor(test_data_dir, 19, (img_width, img_height))

print('Training   data loaded: {}'.format(X_train.shape))
print('Validation data loaded: {}'.format(X_valid.shape))
print('Test       data loaded: {}'.format(X_test.shape))

## classes should be the same
assert(classes == classes1 == classes2)
# Out:
# Training   data loaded: (1460, 224, 224, 3)
# Validation data loaded: (180, 224, 224, 3)
# Test       data loaded: (140, 224, 224, 3)

# %% [markdown]
# # I. Explore DataSet

# %% [markdown]
# ### Visualize Images
# The images are RGB images (3 channels) taken from different angles in the wild. This creates more difficulties for the models to learn from so little data.
# For instance, horns of the goat are of different shape looking from the side and the front. Apart from that, some images have more than one animals which could further reduce the effectiveness of the model.

# %%
## Loading images in their original shape

plt.figure(figsize=(20, 8))
X_train_orig, y_train_orig, classes_orig = dataset_to_4d_tensor(train_data_dir, 19)

for i, (X, y) in enumerate(zip(X_train_orig[:10], y_train_orig[:10])):
    plt.subplot(2, 5, 1 + i)
    plt.title(classes_orig[np.argmax(y)])
    plt.axis('off')
    plt.imshow(X)

# %% [markdown]
# ### RGB histogram

# %%
colors = {'r', 'g', 'b'}

fig, ax = plt.subplots(5,4)
fig.set_figwidth(20)
fig.set_figheight(24)

# For each class
for i in range(19):
    # For each color channel - red, green and blue
    for (chan, color) in zip(range(3), colors):
        row = i//4
        col = i%4
        ax[row,col].set_title(classes[i])
        ax[row,col].set_xlabel('Bins')
        ax[row,col].set_ylabel('# of Pixels')
        ax[row,col].set_xlim([0,255])
        ax[row,col].set_ylim([0,0.011])
        
        # Pull out the data belongs to the class from X_train vector
        # Flatten the images for the entire class 
        # Plot kde for each color channel
        sns.kdeplot(X_train[np.argmax(y_train, axis=1) == i].reshape(-1,3)[:,chan] * 255, color=color, ax=ax[row, col])

# %% [markdown]
# ### Check image count of classes
# Except for sheep and skunk - the images per classes are quite evenly distributed

# %%
plt.figure(figsize=(15,3))
sns.countplot([classes[i] for i in np.argmax(y_train, axis=1)]);

# %% [markdown]
# # II. Benchmark Model
# ### Helper Class, function and generator

# %%
class Metric(Callback):
    def __init__(self, X_test, y_test):
        self.X_test = X_test 
        self.y_test = y_test 
        self.history = pd.DataFrame(columns = ['epoch', 'metric', 'train', 'valid', 'test'])
        self.test_loss = 0
        self.test_acc = 0

    def on_epoch_end(self, epoch, logs={}):
        losses = [epoch, 'loss']
        accuracies = [epoch, 'acc']

        # Get test loss and acc
        loss, acc = self.model.evaluate(self.X_test, self.y_test, verbose=0)
        
        # Prepare row
        losses += [logs['loss'], logs['val_loss'], loss]
        accuracies += [logs['acc'], logs['val_acc'], acc]
        
        # Add to DataFrame
        self.history.loc[epoch * 2] = losses
        self.history.loc[epoch * 2 + 1] = accuracies
        

        
def plot_metric_history(metric_history):
    fig, ax = plt.subplots(1, 2)
    fig.set_figwidth(20)

    sns.color_palette("pastel")

    ax[0].set_title('Loss')
    ax[1].set_title('Accuracy')

    metric_history[metric_history.metric == 'loss'].set_index('epoch').plot(ax=ax[0])
    metric_history[metric_history.metric == 'acc'].set_index('epoch').plot(ax=ax[1])
    
    
def get_min_loss_metric(metric_history):
    min_val_loss = metric_history[metric_history.metric == 'loss'].valid.min()
    min_val_epoch = metric_history[(metric_history.valid == min_val_loss) & (metric_history.metric == 'loss')].epoch
    
    return metric_history[metric_history.epoch == int(min_val_epoch.head(1))]
    

# Create Image Generator for train, validation and test datasets
datagen = ImageDataGenerator(
    rotation_range=10,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
)

datagen.fit(X_train)

# %% [markdown]
# ### Augmented Images

# %%
X_train_augmented, y_train_augmented = datagen.flow(X_train, y_train, batch_size=10, shuffle=True, seed=1).next()

plt.figure(figsize=(20, 8))

for i, (X, y) in enumerate(zip(X_train_augmented, y_train_augmented)):
    plt.subplot(2, 5, 1 + i)
    plt.title(classes[np.argmax(y)])
    plt.axis('off')
    plt.imshow(X)

# %% [markdown]
# ### Benchmark Model Definition

# %%
MODEL=".64-5CNN"

benchmark_model = Sequential()
# Input
benchmark_model.add(InputLayer(input_shape=(img_width, img_height, 3), name='Input'))
    
benchmark_model.add(Conv2D(filters=64, kernel_size=3, strides=1, activation='relu', padding='same', name='Conv_1'))
benchmark_model.add(MaxPool2D(name='MaxPool_2'))

benchmark_model.add(Conv2D(filters=128, kernel_size=3, strides=1, activation='relu', padding='same', name='Conv_3'))
benchmark_model.add(MaxPool2D(name='MaxPool_4'))

benchmark_model.add(Conv2D(filters=256, kernel_size=3, strides=1, activation='relu', padding='same', name='Conv_5'))
benchmark_model.add(MaxPool2D(name='MaxPool_5'))

benchmark_model.add(Conv2D(filters=512, kernel_size=3, strides=1, activation='relu', padding='same', name='Conv_7'))
benchmark_model.add(MaxPool2D(name='MaxPool_7'))
benchmark_model.add(Dropout(0.5, name='Dropout_8'))

benchmark_model.add(Conv2D(filters=512, kernel_size=3, strides=1, activation='relu', padding='same', name='Conv_9'))
benchmark_model.add(MaxPool2D(name='MaxPool_10'))
benchmark_model.add(Dropout(0.4, name='Dropout_11'))

benchmark_model.add(GlobalAveragePooling2D(name='GAP_12'))
benchmark_model.add(Dropout(0.3, name='Dropout_13'))

# Output
benchmark_model.add(Dense(19, activation='softmax', name='Output'))

## Compile Model
benchmark_model.compile(optimizer=optimizers.RMSprop(), loss='categorical_crossentropy', metrics=['accuracy'])

## View Model
benchmark_model.summary()

## Model Output
benchmark_model_weights_path = f'{saved_model_dir}/benchmark_model{MODEL}.{img_width}x{img_height}.weights.best.hdf5'
benchmark_model_metric_path = f'{saved_model_dir}/benchmark_model{MODEL}.{img_width}x{img_height}.metric.hdf5'

## Training Data Generator 
train_data_generator = datagen.flow(X_train, y_train, batch_size=batch_size, shuffle=True, seed=1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           (None, 224, 224, 3)       0
# _________________________________________________________________
# Conv_1 (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# MaxPool_2 (MaxPooling2D)     (None, 112, 112, 64)      0
# _________________________________________________________________
# Conv_3 (Conv2D)              (None, 112, 112, 128)     73856
# _________________________________________________________________
# MaxPool_4 (MaxPooling2D)     (None, 56, 56, 128)       0
# _________________________________________________________________
# Conv_5 (Conv2D)              (None, 56, 56, 256)       295168
# _________________________________________________________________
# MaxPool_5 (MaxPooling2D)     (None, 28, 28, 256)       0
# _________________________________________________________________
# Conv_7 (Conv2D)              (None, 28, 28, 512)       1180160
# _________________________________________________________________
# MaxPool_7 (MaxPooling2D)     (None, 14, 14, 512)       0
# _________________________________________________________________
# Dropout_8 (Dropout)          (None, 14, 14, 512)       0
# _________________________________________________________________
# Conv_9 (Conv2D)              (None, 14, 14, 512)       2359808
# _________________________________________________________________
# MaxPool_10 (MaxPooling2D)    (None, 7, 7, 512)         0
# _________________________________________________________________
# Dropout_11 (Dropout)         (None, 7, 7, 512)         0
# _________________________________________________________________
# GAP_12 (GlobalAveragePooling (None, 512)               0
# _________________________________________________________________
# Dropout_13 (Dropout)         (None, 512)               0
# _________________________________________________________________
# Output (Dense)               (None, 19)                9747
# =================================================================
# Total params: 3,920,531
# Trainable params: 3,920,531
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 100 
retrain = False

## Train 
if retrain or not os.path.exists(benchmark_model_weights_path):
    checkpointer = ModelCheckpoint(filepath=benchmark_model_weights_path, monitor='val_loss', verbose=1, save_best_only=True, )
    earlystopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=1, mode='auto')
    benchmark_metric = Metric(X_test, y_test)
    
    start_time = timeit.default_timer()

    benchmark_model.fit_generator(
                train_data_generator,
                validation_data=(X_valid, y_valid),
                steps_per_epoch = len(X_train) / batch_size,
                epochs=epochs,
                callbacks=[checkpointer, earlystopper, benchmark_metric], 
                verbose=0)
    
    print('\nModel took {:.2f} seconds to train.'.format(timeit.default_timer() - start_time))
    
    benchmark_metric.history.to_pickle(benchmark_model_metric_path)
else:
    print('Model has already been trained.')
# Out:
# Epoch 00000: val_loss improved from inf to 2.93397, saving model to saved_models_capstone/benchmark_model.64-5CNN.224x224.weights.best.hdf5
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss improved from 2.93397 to 2.90994, saving model to saved_models_capstone/benchmark_model.64-5CNN.224x224.weights.best.hdf5
# Epoch 00003: val_loss improved from 2.90994 to 2.54580, saving model to saved_models_capstone/benchmark_model.64-5CNN.224x224.weights.best.hdf5
# Epoch 00004: val_loss improved from 2.54580 to 2.52379, saving model to saved_models_capstone/benchmark_model.64-5CNN.224x224.weights.best.hdf5
# Epoch 00005: val_loss improved from 2.52379 to 2.37080, saving model to saved_models_capstone/benchmark_model.64-5CNN.224x224.weights.best.hdf5
# Epoch 00006: val_loss improved from 2.37080 to 2.27245, saving model to saved_models_capstone/benchmark_model.64-5CNN.224x224.weights.best.hdf5
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss improved from 2.27245 to 2.26769, saving model to saved_models_capstone/benchmark_model.64-5CNN.224x224.weights.best.hdf5
# Epoch 00009: val_loss did not improve
# Epoch 00010: val_loss improved from 2.26769 to 1.90597, saving model to saved_models_capstone/benchmark_model.64-5CNN.224x224.weights.best.hdf5
# Epoch 00011: val_loss did not improve
# Epoch 00012: val_loss improved from 1.90597 to 1.88405, saving model to saved_models_capstone/benchmark_model.64-5CNN.224x224.weights.best.hdf5
# Epoch 00013: val_loss improved from 1.88405 to 1.72867, saving model to saved_models_capstone/benchmark_model.64-5CNN.224x224.weights.best.hdf5
# Epoch 00014: val_loss did not improve
# Epoch 00015: val_loss did not improve
# Epoch 00016: val_loss improved from 1.72867 to 1.52531, saving model to saved_models_capstone/benchmark_model.64-5CNN.224x224.weights.best.hdf5
# Epoch 00017: val_loss did not improve
# Epoch 00018: val_loss improved from 1.52531 to 1.49357, saving model to saved_models_capstone/benchmark_model.64-5CNN.224x224.weights.best.hdf5
# Epoch 00019: val_loss did not improve
# Epoch 00020: val_loss improved from 1.49357 to 1.41798, saving model to saved_models_capstone/benchmark_model.64-5CNN.224x224.weights.best.hdf5
# Epoch 00021: val_loss improved from 1.41798 to 1.41269, saving model to saved_models_capstone/benchmark_model.64-5CNN.224x224.weights.best.hdf5
# Epoch 00022: val_loss did not improve
# Epoch 00023: val_loss improved from 1.41269 to 1.35668, saving model to saved_models_capstone/benchmark_model.64-5CNN.224x224.weights.best.hdf5
# Epoch 00024: val_loss did not improve
# Epoch 00025: val_loss did not improve
# Epoch 00026: val_loss did not improve
# Epoch 00027: val_loss did not improve
# Epoch 00028: val_loss did not improve
# Epoch 00029: val_loss did not improve
# Epoch 00029: early stopping
#
# Model took 259.60 seconds to train.

# %%
benchmark_model.load_weights(benchmark_model_weights_path)
benchmark_metric_history = pd.read_pickle(benchmark_model_metric_path)

plot_metric_history(benchmark_metric_history)
display(get_min_loss_metric(benchmark_metric_history))
# Out:
#    epoch metric     train     valid      test
# 46    23   loss  1.117020  1.356680  1.826603
# 47    23    acc  0.659589  0.627778  0.571429

# %%
y_hat_test = benchmark_model.predict(X_test)
print('Cohen-Kappa Score: {:.4f}'.format(cohen_kappa_score(np.argmax(y_hat_test, axis=1), np.argmax(y_test, axis=1))))
# Out:
# Cohen-Kappa Score: 0.5479

# %% [markdown]
# # III. Transfer Learning - Train a top model based on a pretrain model
# ## Generate bottleneck features
# Bottleneck features are the output of the pretrained model at the point before fully-connected layer.
# At this stage, I'll use a pretrain model with weights trained from imagenet dataset - and connect it with a fully-connected layer (2 categories) for our dog-vs-cat problem.

# %%
## Load pre-trained network
pretrained_model = applications.VGG19(include_top=False, weights='imagenet')

bottleneck_features_train_data = f'{saved_model_dir}/{pretrained_model.name}.{img_width}x{img_height}.bottleneck_features_train.npy'
bottleneck_features_valid_data = f'{saved_model_dir}/{pretrained_model.name}.{img_width}x{img_height}.bottleneck_features_valid.npy'
bottleneck_features_test_data = f'{saved_model_dir}/{pretrained_model.name}.{img_width}x{img_height}.bottleneck_features_test.npy'

train_X_generator = datagen.flow(X_train, batch_size=batch_size, shuffle=False)

## Generate bottleneck features - output of pretrained model
# Training
if not os.path.exists(bottleneck_features_train_data):
    X_train_bottleneck = pretrained_model.predict_generator(train_X_generator, steps=len(X_train) / batch_size)
    np.save(open(bottleneck_features_train_data, 'wb'), X_train_bottleneck)
    print('Training   bottleneck features saved.')
else:
    print('Training   bottleneck features already exist.')

# Validation
if not os.path.exists(bottleneck_features_valid_data):
    X_valid_bottleneck = pretrained_model.predict(X_valid)
    np.save(open(bottleneck_features_valid_data, 'wb'), X_valid_bottleneck)
    print('Validation bottleneck features saved.')
else:
    print('Validation bottleneck features already exist.')
    
# Testing
if not os.path.exists(bottleneck_features_test_data):
    X_test_bottleneck = pretrained_model.predict(X_test)
    np.save(open(bottleneck_features_test_data, 'wb'), X_test_bottleneck)
    print('Testing    bottleneck features saved.')
else:
    print('Testing    bottleneck features already exist.')
# Out:
# Training   bottleneck features already exist.
# Validation bottleneck features already exist.
# Testing    bottleneck features already exist.

# %% [markdown]
# ## Define Top Model

# %%
# Inputs
X_train_bottleneck = np.load(open(bottleneck_features_train_data, 'rb'))
X_valid_bottleneck = np.load(open(bottleneck_features_valid_data, 'rb'))
X_test_bottleneck = np.load(open(bottleneck_features_test_data, 'rb'))

######### TOP MODEL ######################################
epochs = 500
retrain = False
top_model_name = 'gap' 

top_model = Sequential()
top_model.add(GlobalAveragePooling2D(input_shape=X_train_bottleneck.shape[1:], name='GAP'))
top_model.add(Dropout(0.7, name='Dropout'))
top_model.add(Dense(19, name='FC'))
top_model.add(Activation('softmax', name='Softmax'))
#top_model.add(Dense(19, activation='softmax', name='Output'))
##########################################################


#top_model.compile(optimizer=optimizers.Adamax(lr=0.025),
top_model.compile(optimizer=optimizers.RMSprop(),
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

top_model.summary()

top_model_weights_path = f'{saved_model_dir}/{pretrained_model.name}.{top_model_name}.{img_width}x{img_height}.top_model.weights.best.hdf5'
top_model_metric_path = f'{saved_model_dir}/{pretrained_model.name}.{top_model_name}.{img_width}x{img_height}.metric.hdf5'
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# GAP (GlobalAveragePooling2D) (None, 512)               0
# _________________________________________________________________
# Dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# FC (Dense)                   (None, 19)                9747
# _________________________________________________________________
# Softmax (Activation)         (None, 19)                0
# =================================================================
# Total params: 9,747
# Trainable params: 9,747
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train Top Model

# %%
if retrain or not os.path.exists(top_model_weights_path):

    checkpointer = ModelCheckpoint(filepath=top_model_weights_path, monitor='val_loss', verbose=1, save_best_only=True)
    earlystopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, mode='auto')
    top_metric = Metric(X_test_bottleneck, y_test)

    start_time = timeit.default_timer()
    
    top_model.fit(X_train_bottleneck, y_train,
              epochs=epochs,
              batch_size=batch_size,
              validation_data=(X_valid_bottleneck, y_valid),
              callbacks=[checkpointer, earlystopper, top_metric], verbose=0)
    
    print('\nTop Model took {:.2f} seconds to train.'.format(timeit.default_timer() - start_time))
    
    top_metric.history.to_pickle(top_model_metric_path)
else:
    print('Model already trained.')
# Out:
# Epoch 00000: val_loss improved from inf to 2.89821, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00001: val_loss improved from 2.89821 to 2.81934, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00002: val_loss improved from 2.81934 to 2.73419, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00003: val_loss improved from 2.73419 to 2.67069, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00004: val_loss improved from 2.67069 to 2.60736, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00005: val_loss improved from 2.60736 to 2.55514, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00006: val_loss improved from 2.55514 to 2.50272, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00007: val_loss improved from 2.50272 to 2.45655, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00008: val_loss improved from 2.45655 to 2.40974, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00009: val_loss improved from 2.40974 to 2.37782, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00010: val_loss improved from 2.37782 to 2.33218, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00011: val_loss improved from 2.33218 to 2.29938, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00012: val_loss improved from 2.29938 to 2.26880, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00013: val_loss improved from 2.26880 to 2.24412, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00014: val_loss improved from 2.24412 to 2.20624, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00015: val_loss improved from 2.20624 to 2.18159, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00016: val_loss improved from 2.18159 to 2.15489, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00017: val_loss improved from 2.15489 to 2.13317, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00018: val_loss improved from 2.13317 to 2.10657, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00019: val_loss improved from 2.10657 to 2.09100, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00020: val_loss improved from 2.09100 to 2.06342, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00021: val_loss improved from 2.06342 to 2.04623, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00022: val_loss improved from 2.04623 to 2.03220, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00023: val_loss improved from 2.03220 to 2.01060, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00024: val_loss improved from 2.01060 to 1.99429, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00025: val_loss improved from 1.99429 to 1.97702, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00026: val_loss improved from 1.97702 to 1.95992, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00027: val_loss improved from 1.95992 to 1.95609, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00028: val_loss improved from 1.95609 to 1.93288, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00029: val_loss improved from 1.93288 to 1.92385, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00030: val_loss improved from 1.92385 to 1.90743, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00031: val_loss improved from 1.90743 to 1.89319, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00032: val_loss improved from 1.89319 to 1.88841, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00033: val_loss improved from 1.88841 to 1.87646, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00034: val_loss improved from 1.87646 to 1.86117, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00035: val_loss improved from 1.86117 to 1.84369, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00036: val_loss improved from 1.84369 to 1.83615, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00037: val_loss improved from 1.83615 to 1.82013, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00038: val_loss improved from 1.82013 to 1.81534, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00039: val_loss improved from 1.81534 to 1.79918, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00040: val_loss improved from 1.79918 to 1.79312, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00041: val_loss did not improve
# Epoch 00042: val_loss improved from 1.79312 to 1.77738, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00043: val_loss did not improve
# Epoch 00044: val_loss improved from 1.77738 to 1.77144, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00045: val_loss improved from 1.77144 to 1.74882, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00046: val_loss improved from 1.74882 to 1.74135, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00047: val_loss did not improve
# Epoch 00048: val_loss improved from 1.74135 to 1.73580, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00049: val_loss improved from 1.73580 to 1.72419, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00050: val_loss did not improve
# Epoch 00051: val_loss improved from 1.72419 to 1.71744, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00052: val_loss improved from 1.71744 to 1.71116, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00053: val_loss improved from 1.71116 to 1.70856, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00054: val_loss improved from 1.70856 to 1.70031, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00055: val_loss improved from 1.70031 to 1.69565, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00056: val_loss improved from 1.69565 to 1.68187, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00057: val_loss improved from 1.68187 to 1.67884, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00058: val_loss improved from 1.67884 to 1.67840, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00059: val_loss improved from 1.67840 to 1.66833, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00060: val_loss improved from 1.66833 to 1.66538, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00061: val_loss improved from 1.66538 to 1.65663, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00062: val_loss did not improve
# Epoch 00063: val_loss improved from 1.65663 to 1.65229, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00064: val_loss improved from 1.65229 to 1.64899, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00065: val_loss improved from 1.64899 to 1.64548, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00066: val_loss improved from 1.64548 to 1.64269, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00067: val_loss improved from 1.64269 to 1.63319, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00068: val_loss improved from 1.63319 to 1.62404, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00069: val_loss did not improve
# Epoch 00070: val_loss improved from 1.62404 to 1.61141, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00071: val_loss did not improve
# Epoch 00072: val_loss did not improve
# Epoch 00073: val_loss did not improve
# Epoch 00074: val_loss improved from 1.61141 to 1.60807, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00075: val_loss improved from 1.60807 to 1.59232, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00076: val_loss improved from 1.59232 to 1.59131, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00077: val_loss did not improve
# Epoch 00078: val_loss improved from 1.59131 to 1.58778, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00079: val_loss did not improve
# Epoch 00080: val_loss improved from 1.58778 to 1.58240, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00081: val_loss improved from 1.58240 to 1.57923, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00082: val_loss improved from 1.57923 to 1.57327, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00083: val_loss improved from 1.57327 to 1.56760, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00084: val_loss did not improve
# Epoch 00085: val_loss improved from 1.56760 to 1.56166, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00086: val_loss did not improve
# Epoch 00087: val_loss improved from 1.56166 to 1.55951, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00088: val_loss did not improve
# Epoch 00089: val_loss improved from 1.55951 to 1.55885, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00090: val_loss improved from 1.55885 to 1.55797, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00091: val_loss improved from 1.55797 to 1.55757, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00092: val_loss improved from 1.55757 to 1.54726, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00093: val_loss did not improve
# Epoch 00094: val_loss did not improve
# Epoch 00095: val_loss improved from 1.54726 to 1.54214, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00096: val_loss improved from 1.54214 to 1.53994, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00097: val_loss did not improve
# Epoch 00098: val_loss improved from 1.53994 to 1.53682, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00099: val_loss improved from 1.53682 to 1.53174, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00100: val_loss improved from 1.53174 to 1.53131, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00101: val_loss did not improve
# Epoch 00102: val_loss improved from 1.53131 to 1.52472, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00103: val_loss did not improve
# Epoch 00104: val_loss improved from 1.52472 to 1.52131, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00105: val_loss improved from 1.52131 to 1.51633, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00106: val_loss did not improve
# Epoch 00107: val_loss did not improve
# Epoch 00108: val_loss improved from 1.51633 to 1.50864, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00109: val_loss improved from 1.50864 to 1.50697, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00110: val_loss did not improve
# Epoch 00111: val_loss did not improve
# Epoch 00112: val_loss did not improve
# Epoch 00113: val_loss improved from 1.50697 to 1.50279, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00114: val_loss improved from 1.50279 to 1.50023, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00115: val_loss did not improve
# Epoch 00116: val_loss did not improve
# Epoch 00117: val_loss improved from 1.50023 to 1.49766, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00118: val_loss improved from 1.49766 to 1.49563, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00119: val_loss did not improve
# Epoch 00120: val_loss improved from 1.49563 to 1.49392, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00121: val_loss did not improve
# Epoch 00122: val_loss improved from 1.49392 to 1.49368, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00123: val_loss improved from 1.49368 to 1.48219, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00124: val_loss improved from 1.48219 to 1.47861, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00125: val_loss did not improve
# Epoch 00126: val_loss did not improve
# Epoch 00127: val_loss did not improve
# Epoch 00128: val_loss did not improve
# Epoch 00129: val_loss improved from 1.47861 to 1.47380, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00130: val_loss did not improve
# Epoch 00131: val_loss did not improve
# Epoch 00132: val_loss did not improve
# Epoch 00133: val_loss improved from 1.47380 to 1.47135, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00134: val_loss improved from 1.47135 to 1.47072, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00135: val_loss improved from 1.47072 to 1.46860, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00136: val_loss did not improve
# Epoch 00137: val_loss did not improve
# Epoch 00138: val_loss did not improve
# Epoch 00139: val_loss improved from 1.46860 to 1.46030, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00140: val_loss did not improve
# Epoch 00141: val_loss did not improve
# Epoch 00142: val_loss improved from 1.46030 to 1.45967, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00143: val_loss improved from 1.45967 to 1.45933, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00144: val_loss improved from 1.45933 to 1.45313, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00145: val_loss did not improve
# Epoch 00146: val_loss improved from 1.45313 to 1.44638, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00147: val_loss did not improve
# Epoch 00148: val_loss did not improve
# Epoch 00149: val_loss improved from 1.44638 to 1.44553, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00150: val_loss improved from 1.44553 to 1.44060, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00151: val_loss did not improve
# Epoch 00152: val_loss did not improve
# Epoch 00153: val_loss did not improve
# Epoch 00154: val_loss did not improve
# Epoch 00155: val_loss improved from 1.44060 to 1.43253, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00156: val_loss did not improve
# Epoch 00157: val_loss did not improve
# Epoch 00158: val_loss did not improve
# Epoch 00159: val_loss improved from 1.43253 to 1.43127, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00160: val_loss improved from 1.43127 to 1.42999, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00161: val_loss did not improve
# Epoch 00162: val_loss did not improve
# Epoch 00163: val_loss did not improve
# Epoch 00164: val_loss did not improve
# Epoch 00165: val_loss improved from 1.42999 to 1.41999, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00166: val_loss did not improve
# Epoch 00167: val_loss did not improve
# Epoch 00168: val_loss improved from 1.41999 to 1.41646, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00169: val_loss did not improve
# Epoch 00170: val_loss did not improve
# Epoch 00171: val_loss did not improve
# Epoch 00172: val_loss did not improve
# Epoch 00173: val_loss did not improve
# Epoch 00174: val_loss did not improve
# Epoch 00175: val_loss did not improve
# Epoch 00176: val_loss did not improve
# Epoch 00177: val_loss improved from 1.41646 to 1.41444, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00178: val_loss improved from 1.41444 to 1.40846, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00179: val_loss did not improve
# Epoch 00180: val_loss did not improve
# Epoch 00181: val_loss did not improve
# Epoch 00182: val_loss did not improve
# Epoch 00183: val_loss did not improve
# Epoch 00184: val_loss did not improve
# Epoch 00185: val_loss did not improve
# Epoch 00186: val_loss did not improve
# Epoch 00187: val_loss improved from 1.40846 to 1.40652, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00188: val_loss improved from 1.40652 to 1.40119, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00189: val_loss did not improve
# Epoch 00190: val_loss did not improve
# Epoch 00191: val_loss did not improve
# Epoch 00192: val_loss improved from 1.40119 to 1.40102, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00193: val_loss did not improve
# Epoch 00194: val_loss did not improve
# Epoch 00195: val_loss did not improve
# Epoch 00196: val_loss did not improve
# Epoch 00197: val_loss did not improve
# Epoch 00198: val_loss did not improve
# Epoch 00199: val_loss improved from 1.40102 to 1.39936, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00200: val_loss did not improve
# Epoch 00201: val_loss did not improve
# Epoch 00202: val_loss did not improve
# Epoch 00203: val_loss improved from 1.39936 to 1.39350, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00204: val_loss improved from 1.39350 to 1.39195, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00205: val_loss did not improve
# Epoch 00206: val_loss improved from 1.39195 to 1.38731, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00207: val_loss did not improve
# Epoch 00208: val_loss improved from 1.38731 to 1.38687, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00209: val_loss did not improve
# Epoch 00210: val_loss improved from 1.38687 to 1.38555, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00211: val_loss did not improve
# Epoch 00212: val_loss did not improve
# Epoch 00213: val_loss improved from 1.38555 to 1.38362, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00214: val_loss improved from 1.38362 to 1.37893, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00215: val_loss did not improve
# Epoch 00216: val_loss did not improve
# Epoch 00217: val_loss did not improve
# Epoch 00218: val_loss did not improve
# Epoch 00219: val_loss improved from 1.37893 to 1.37727, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00220: val_loss did not improve
# Epoch 00221: val_loss did not improve
# Epoch 00222: val_loss improved from 1.37727 to 1.37568, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00223: val_loss improved from 1.37568 to 1.37329, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00224: val_loss improved from 1.37329 to 1.36570, saving model to saved_models_capstone/vgg19.gap.224x224.top_model.weights.best.hdf5
# Epoch 00225: val_loss did not improve
# Epoch 00226: val_loss did not improve
# Epoch 00227: val_loss did not improve
# Epoch 00228: val_loss did not improve
# Epoch 00229: val_loss did not improve
# Epoch 00230: val_loss did not improve
# Epoch 00231: val_loss did not improve
# Epoch 00232: val_loss did not improve
# Epoch 00233: val_loss did not improve
# Epoch 00234: val_loss did not improve
# Epoch 00235: val_loss did not improve
# Epoch 00235: early stopping
#
# Top Model took 40.83 seconds to train.

# %% [markdown]
# ## Accuracy

# %%
top_model.load_weights(top_model_weights_path)
top_metric_history = pd.read_pickle(top_model_metric_path)

plot_metric_history(top_metric_history)
display(get_min_loss_metric(top_metric_history))
# Out:
#     epoch metric     train     valid      test
# 448   224   loss  1.469626  1.365698  1.410381
# 449   224    acc  0.547260  0.588889  0.600000

# %%
y_hat_test = top_model.predict(X_test_bottleneck)
print('Cohen-Kappa Score: {:.4f}'.format(cohen_kappa_score(np.argmax(y_hat_test, axis=1), np.argmax(y_test, axis=1))))
# Out:
# Cohen-Kappa Score: 0.5777

# %% [markdown]
# # II. Fine Tune Last CNN Block
# ## Build model from pretrained and the top model

# %%
fine_tune_model_weights_path = f'{saved_model_dir}/{pretrained_model.name}.{top_model_name}.{img_width}x{img_height}.fine_tune.weights.best.hdf5'
fine_tune_model_metric_path = f'{saved_model_dir}/{pretrained_model.name}.{top_model_name}.{img_width}x{img_height}.fine_tune.metric.hdf5'

## Reload (to make sure) pretrained and top_model weight
pretrained_model = applications.VGG19(include_top=False, weights='imagenet')
top_model.load_weights(top_model_weights_path)

## Build model from pretrain and top model
model = Sequential()
for l in pretrained_model.layers:
    model.add(l)
    
for l in top_model.layers:
    model.add(l)

## Lock layers until the last ConvNet block
lock_until = 17  

for n, layer in enumerate(model.layers):
    if n < lock_until:
        layer.trainable = False
    else:
        layer.trainable = True

## Compile
model.compile(optimizer=optimizers.SGD(lr=1e-4, momentum=0.9),
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, None, None, 3)     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# GAP (GlobalAveragePooling2D) (None, 512)               0
# _________________________________________________________________
# Dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# FC (Dense)                   (None, 19)                9747
# _________________________________________________________________
# Softmax (Activation)         (None, 19)                0
# =================================================================
# Total params: 20,034,131
# Trainable params: 9,448,979
# Non-trainable params: 10,585,152
# _________________________________________________________________

# %% [markdown]
# ## Show model layers
# Only block 5 ConvNet and the top model (FC layer) is trainable

# %%
for i, l in enumerate(model.layers):
    print('{:<2}: {:>27}({:^7}) - trainable={}'.format(i, l.name, l.activation.__name__ if hasattr(l,'activation') else '', l.trainable))
# Out:
# 0 :                     input_2(       ) - trainable=False
# 1 :                block1_conv1( relu  ) - trainable=False
# 2 :                block1_conv2( relu  ) - trainable=False
# 3 :                 block1_pool(       ) - trainable=False
# 4 :                block2_conv1( relu  ) - trainable=False
# 5 :                block2_conv2( relu  ) - trainable=False
# 6 :                 block2_pool(       ) - trainable=False
# 7 :                block3_conv1( relu  ) - trainable=False
# 8 :                block3_conv2( relu  ) - trainable=False
# 9 :                block3_conv3( relu  ) - trainable=False
# 10:                block3_conv4( relu  ) - trainable=False
# 11:                 block3_pool(       ) - trainable=False
# 12:                block4_conv1( relu  ) - trainable=False
# 13:                block4_conv2( relu  ) - trainable=False
# 14:                block4_conv3( relu  ) - trainable=False
# 15:                block4_conv4( relu  ) - trainable=False
# 16:                 block4_pool(       ) - trainable=False
# 17:                block5_conv1( relu  ) - trainable=True
# 18:                block5_conv2( relu  ) - trainable=True
# 19:                block5_conv3( relu  ) - trainable=True
# 20:                block5_conv4( relu  ) - trainable=True
# 21:                 block5_pool(       ) - trainable=True
# 22:                         GAP(       ) - trainable=True
# 23:                     Dropout(       ) - trainable=True
# 24:                          FC(linear ) - trainable=True
# 25:                     Softmax(softmax) - trainable=True

# %% [markdown]
# ## Train
# As [Keras Blog](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html) pointed out, I have to use SGD here as optimizer - I tried RMSprop which brought the validation accuracy straight back to 50% (it's like almost restarting the entire training)

# %%
retrain = False
epochs = 100

if retrain or not os.path.exists(fine_tune_model_weights_path):
    checkpointer = ModelCheckpoint(filepath=fine_tune_model_weights_path, monitor='val_loss', verbose=1, save_best_only=True)
    earlystopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=1, mode='auto')
    metric = Metric(X_test, y_test)
    
    start_time = timeit.default_timer()

    model.fit_generator(
                train_data_generator,
                validation_data=(X_valid, y_valid),
                steps_per_epoch = len(X_train) / batch_size,
                epochs=epochs,
                callbacks=[checkpointer, earlystopper, metric], 
                verbose=0)
    
    metric.history.to_pickle(fine_tune_model_metric_path)
    
    print('\nTop Model took {:.2f} seconds to train.'.format(timeit.default_timer() - start_time))
    
else:
    print('Model already trained.')
# Out:
# Epoch 00000: val_loss improved from inf to 1.17743, saving model to saved_models_capstone/vgg19.gap.224x224.fine_tune.weights.best.hdf5
# Epoch 00001: val_loss improved from 1.17743 to 1.07508, saving model to saved_models_capstone/vgg19.gap.224x224.fine_tune.weights.best.hdf5
# Epoch 00002: val_loss improved from 1.07508 to 1.00546, saving model to saved_models_capstone/vgg19.gap.224x224.fine_tune.weights.best.hdf5
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss improved from 1.00546 to 0.93148, saving model to saved_models_capstone/vgg19.gap.224x224.fine_tune.weights.best.hdf5
# Epoch 00005: val_loss improved from 0.93148 to 0.85479, saving model to saved_models_capstone/vgg19.gap.224x224.fine_tune.weights.best.hdf5
# Epoch 00006: val_loss improved from 0.85479 to 0.82746, saving model to saved_models_capstone/vgg19.gap.224x224.fine_tune.weights.best.hdf5
# Epoch 00007: val_loss improved from 0.82746 to 0.78405, saving model to saved_models_capstone/vgg19.gap.224x224.fine_tune.weights.best.hdf5
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Epoch 00010: val_loss improved from 0.78405 to 0.75229, saving model to saved_models_capstone/vgg19.gap.224x224.fine_tune.weights.best.hdf5
# Epoch 00011: val_loss improved from 0.75229 to 0.71616, saving model to saved_models_capstone/vgg19.gap.224x224.fine_tune.weights.best.hdf5
# Epoch 00012: val_loss did not improve
# Epoch 00013: val_loss did not improve
# Epoch 00014: val_loss improved from 0.71616 to 0.64424, saving model to saved_models_capstone/vgg19.gap.224x224.fine_tune.weights.best.hdf5
# Epoch 00015: val_loss did not improve
# Epoch 00016: val_loss did not improve
# Epoch 00017: val_loss improved from 0.64424 to 0.63214, saving model to saved_models_capstone/vgg19.gap.224x224.fine_tune.weights.best.hdf5
# Epoch 00018: val_loss did not improve
# Epoch 00019: val_loss improved from 0.63214 to 0.62208, saving model to saved_models_capstone/vgg19.gap.224x224.fine_tune.weights.best.hdf5
# Epoch 00020: val_loss improved from 0.62208 to 0.61067, saving model to saved_models_capstone/vgg19.gap.224x224.fine_tune.weights.best.hdf5
# Epoch 00021: val_loss improved from 0.61067 to 0.59089, saving model to saved_models_capstone/vgg19.gap.224x224.fine_tune.weights.best.hdf5
# Epoch 00022: val_loss did not improve
# Epoch 00023: val_loss did not improve
# Epoch 00024: val_loss improved from 0.59089 to 0.57731, saving model to saved_models_capstone/vgg19.gap.224x224.fine_tune.weights.best.hdf5
# Epoch 00025: val_loss did not improve
# Epoch 00026: val_loss did not improve
# Epoch 00027: val_loss did not improve
# Epoch 00028: val_loss did not improve
# Epoch 00029: val_loss did not improve
# Epoch 00030: val_loss did not improve
# Epoch 00030: early stopping
#
# Top Model took 375.82 seconds to train.

# %% [markdown]
# ## After fine-tuning
# Accuracy increased significantly after fine-tuning the last ConvNet block and the fully-connected layer (top model)

# %%
model.load_weights(fine_tune_model_weights_path)
fine_tune_metric_history = pd.read_pickle(fine_tune_model_metric_path)

plot_metric_history(fine_tune_metric_history)
display(get_min_loss_metric(fine_tune_metric_history))
# Out:
#    epoch metric     train     valid      test
# 48    24   loss  0.360831  0.577308  0.929925
# 49    24    acc  0.874658  0.811111  0.800000

# %%
y_hat_test = model.predict(X_test)
print('Cohen-Kappa Score: {:.4f}'.format(cohen_kappa_score(np.argmax(y_hat_test, axis=1), np.argmax(y_test, axis=1))))
# Out:
# Cohen-Kappa Score: 0.7890

# %% [markdown]
# ## Result

# %%
from sklearn.metrics import confusion_matrix

# heatmap
x = pd.DataFrame(confusion_matrix(np.argmax(y_test,axis=1), np.argmax(y_hat_test, axis=1)), columns=classes, index=classes)
plt.figure(figsize=(10,8))
sns.heatmap(x);

# %% [markdown]
# # III. What the CNN is seeing

# %%
import scipy   

target_size=(img_width, img_height)
    
# Location of the last cnn and output layer
last_cnn_layer = -6  # the last convolution layer - before the MaxPool layer
output_layer = -2    # the last layer is softmax activation in the current setting

# Build a new model which taks the models input as input and produces two outputs - the last cnn layer and the model output layer
new_model = Model(inputs=model.input, outputs=(model.layers[last_cnn_layer].get_output_at(1), model.layers[output_layer].get_output_at(1)))

# %%
my_test_dir = 'my_image/test/'
plt.figure(figsize=(18, 12))

for i, f in enumerate(os.listdir(my_test_dir)):
    
    img_path = os.path.join(my_test_dir, f)
    label = f.split('.')[0]
    
    # get filtered images from convolutional output + model prediction vector
    last_conv_output, pred_vec = new_model.predict(path_to_4d_tensor(img_path, target_size))
    last_conv_output = np.squeeze(last_conv_output)  # (1, 14, 14, 512) --> (14, 14, 512)
    pred = np.argmax(pred_vec) # get predicted class
    
    all_fc_layer_weights = model.layers[output_layer].get_weights()[0]
    fc_layer_weights = all_fc_layer_weights[:, pred] * -1 # dim: (512,) 

    # get class activation map for object class that is predicted to be in the image
    activation_map = np.dot(last_conv_output, fc_layer_weights)
    
    # upsampling
    activation_map_zoomed = scipy.ndimage.zoom(activation_map, (16, 16), order=1) # 14x14 --> 224x224

    # overlay
    im = path_to_3d_tensor(img_path, target_size)
    plt.subplot(3, 5, 1 + i)
    plt.imshow(im, alpha=0.5) # plot image
    plt.imshow(activation_map_zoomed, cmap='jet', alpha=0.5)  # plot class activation map
    plt.title(f'{label}, Predict: {classes[pred]}');  # show prediction class 
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# # IV. Localization

# %%
import scipy   

def img_path_to_tensor(img_path):
    img = image.load_img(img_path, target_size=(img_width, img_height))
    x = image.img_to_array(img) / 255   # (224, 224, 3)
    return np.expand_dims(x, axis=0) # (1, 224, 224, 3)
    
# Location of the last cnn and output layer
last_cnn_layer = -6  # the last convolution layer - before the MaxPool layer
output_layer = -2    # the last layer is softmax activation in the current setting

# Build a new model which taks the models input as input and produces two outputs - the last cnn layer and the model output layer

new_model = Model(inputs=model.input, outputs=(model.layers[last_cnn_layer].get_output_at(1), model.layers[output_layer].get_output_at(1))) 

# Test Image - not in the train/valid/test dataset
img_path = 'my_image/panda_x2.jpg'

# %%
# get filtered images from convolutional output + model prediction vector
last_conv_output, pred_vec = new_model.predict(img_path_to_tensor(img_path))
last_conv_output = np.squeeze(last_conv_output)  # (1, 14, 14, 512) --> (14, 14, 512)
pred = np.argmax(pred_vec) # get predicted class

# Reverse downsampling - when reaching the last Conv layer, the model downsampled 4 times from (224, 224) to (14, 14) 
#cnn_weights_zoomed = scipy.ndimage.zoom(last_conv_output, (16, 16, 1), order=1) # (14, 14, 512) --> (224, 224, 512)

# get FC layer weights
all_fc_layer_weights = model.layers[output_layer].get_weights()[0]
fc_layer_weights = all_fc_layer_weights[:, pred] * -1 # dim: (512,) 

# get class activation map for object class that is predicted to be in the image
activation_map = np.dot(last_conv_output, fc_layer_weights)

# %%
fig,ax = plt.subplots(1,2)
fig.set_figwidth(10)

# Show image
im = img_path_to_tensor(img_path).squeeze()
ax[0].imshow(im, alpha=1);

# Show Activation Map
ax[1].imshow(activation_map, cmap='jet')  # plot class activation map
ax[1].set_title(classes[pred]);  # show prediction class

# %%
# upsampling
activation_map_zoomed = scipy.ndimage.zoom(activation_map, (16, 16), order=1) # 14x14 --> 224x224

# overlay
fig,ax = plt.subplots()
ax.imshow(im, alpha=0.5) # plot image
ax.imshow(activation_map_zoomed, cmap='jet', alpha=0.5)  # plot class activation map
ax.set_title(classes[pred]);  # show prediction class
